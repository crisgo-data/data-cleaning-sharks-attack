# %%
# %pip install ipython
# %pip install seaborn
# !pip install --upgrade datetime.
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Invalid requirement: 'datetime.'

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

import numpy as np

import warnings
warnings.filterwarnings('ignore')

# para pintar
import pylab as plt
import seaborn as sns
import datetime
import re

# para que salga el grafico
# %matplotlib inline

# %%
import zipfile

zf=zipfile.ZipFile(r'C:\Users\usuario\Desktop\data-cleaning-sharks-attack\archive.zip')

attack = pd.read_csv(zf.open('attacks.csv'), encoding= "ISO-8859-1", nrows=1e4)

attack
# Out:
#      Case Number         Date    Year        Type    Country             Area  \
# 0     2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1     2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2     2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3     2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4     2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
# ...          ...          ...     ...         ...        ...              ...
# 9995         NaN          NaN     NaN         NaN        NaN              NaN
# 9996         NaN          NaN     NaN         NaN        NaN              NaN
# 9997         NaN          NaN     NaN         NaN        NaN              NaN
# 9998         NaN          NaN     NaN         NaN        NaN              NaN
# 9999         NaN          NaN     NaN         NaN        NaN              NaN
#
# ...

# %%
attack.shape
# Out:
# (10000, 24)

# %%
attack.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
attack.Country.value_counts()
# Out:
# USA                       2229
# AUSTRALIA                 1338
# SOUTH AFRICA               579
# PAPUA NEW GUINEA           134
# NEW ZEALAND                128
#                           ...
# MALDIVE ISLANDS              1
# NICARAGUA                    1
# NORTH SEA                    1
# RED SEA / INDIAN OCEAN       1
# CEYLON (SRI LANKA)           1
# Name: Country, Length: 212, dtype: int64

# %%
attack.dtypes
# Out:
# Case Number                object
# Date                       object
# Year                      float64
# Type                       object
# Country                    object
# Area                       object
# Location                   object
# Activity                   object
# Name                       object
# Sex                        object
# Age                        object
# Injury                     object
# Fatal (Y/N)                object
# Time                       object
# Species                    object
# Investigator or Source     object
# pdf                        object
# href formula               object
# href                       object
# Case Number.1              object
# Case Number.2              object
# original order            float64
# Unnamed: 22                object
# Unnamed: 23                object
# dtype: object

# %%
attack.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8701 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
# ...

# %%
attack.describe(include='all').T
# Out:
#                          count unique  \
# Case Number               8701   6286
# Date                      6302   5433
# Year                    6300.0    NaN
# Type                      6298      8
# Country                   6252    212
# Area                      5847    825
# Location                  5762   4108
# Activity                  5758   1532
# Name                      6092   5230
# Sex                       5737      6
# Age                       3471    157
# Injury                    6274   3737
# Fatal (Y/N)               5763      8
# Time                      2948    366
# Species                   3464   1549
# Investigator or Source    6285   4969
# pdf                       6302   6291
# href formula              6301   6290
# href                      6302   6285
# Case Number.1             6302   6285
# Case Number.2             6302   6286
# original order          6309.0    NaN
# Unnamed: 22                  1      1
# ...

# %%
num_attack=attack.select_dtypes(include=[np.number])

num_attack.columns.values
# Out:
# array(['Year', 'original order'], dtype=object)

# %%
def check_nan(df: pd.DataFrame) -> None:
    
    """Recibe un dataframe y enseña % de valores nulos y la grafica"""
    
    nan_cols = df.isna().mean()  * 100  # porcentaje de nulo en cada columna

    display(f'N nan cols: {len(nan_cols[nan_cols>0])}')
    display(nan_cols[nan_cols>0])
    
    # grafico de nulos en el dataframe
    plt.figure(figsize=(10, 6))  # inicia la figura y establece el tamaño

    sns.heatmap(df.isna(),   # datos
                yticklabels=False,
                cmap='viridis',
                cbar=False
               )

    plt.show();

# %%
check_nan(attack)
# Out:
# 'N nan cols: 24'
# Case Number               12.99
# Date                      36.98
# Year                      37.00
# Type                      37.02
# Country                   37.48
# Area                      41.53
# Location                  42.38
# Activity                  42.42
# Name                      39.08
# Sex                       42.63
# Age                       65.29
# Injury                    37.26
# Fatal (Y/N)               42.37
# Time                      70.52
# Species                   65.36
# Investigator or Source    37.15
# pdf                       36.98
# href formula              36.99
# href                      36.98
# Case Number.1             36.98
# Case Number.2             36.98
# original order            36.91
# Unnamed: 22               99.99
# Unnamed: 23               99.98
# dtype: float64

# %%
#Analizamos ahora el porcentaje de Nulos para empezar a rellenarlos ya que no podemos eliminar columnas

# %%
nan_cols = attack.isna().mean()  * 100  # porcentaje de nulo en cada columna

nan_cols[nan_cols>0]
# Out:
# Case Number               12.99
# Date                      36.98
# Year                      37.00
# Type                      37.02
# Country                   37.48
# Area                      41.53
# Location                  42.38
# Activity                  42.42
# Name                      39.08
# Sex                       42.63
# Age                       65.29
# Injury                    37.26
# Fatal (Y/N)               42.37
# Time                      70.52
# Species                   65.36
# Investigator or Source    37.15
# pdf                       36.98
# href formula              36.99
# href                      36.98
# Case Number.1             36.98
# Case Number.2             36.98
# original order            36.91
# Unnamed: 22               99.99
# Unnamed: 23               99.98
# dtype: float64

# %%
#eliminamos las filas finales del archivo que directamente son todas nulas.Es decir a partir del indice 6297 hasta el 10000

# %%
attack = attack.drop(attack.index[6297:10000])

# %%
attack.head(5)
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   Age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F   11
# 2                    Habush, Oahu      Surfing      John Denges    M   48
# 3              Arrawarra Headland      Surfing             male    M  NaN
# 4                        La Ticla  Free diving   Gustavo Ramos     M  NaN
#
#                                               Injury Fatal (Y/N)  \
# ...

# %%
"""Hay varias columnas que se podrían rellenar directamente con 'Unkown' pero hay otras que se
correlacionan entre ellas y podrían rellenarse con datos verdaderos"""
# Out:
# "Hay varias columnas que se podrían rellenar directamente con 'Unkown' pero hay otras que se\ncorrelacionan entre ellas y podrían rellenarse con datos verdaderos"

# %%
"""Voy a ir columna por columna para saber los valores a los que puedo darles un valor concreto y sino sustituirlas por 'unknown'"""
# Out:
# "Voy a ir columna por columna para saber los valores a los que puedo darles un valor concreto y sino sustituirlas por 'unknown'"

# %%
#eliminar primero filas duplicadas
attack = attack.drop_duplicates()

# %%
attack['Date'].value_counts()
# Out:
# 1957           11
# 1942            9
# 1956            8
# 1950            7
# 1941            7
#                ..
# 11-Dec-1994     1
# 13-Dec-1994     1
# 18-Dec-1994     1
# 30-Dec-1994     1
# 07-Nov-1975     1
# Name: Date, Length: 5429, dtype: int64

# %%
class CleanExcel():

    #Se inicializa la clase
    def __init__(self) -> None:
        pass

    #Se crea una función dentro de la clase para el parseo del csv y limpieza
    def parse_csv(self):
        #Se abre y se establece el encoding en latin-1 para que no de problemas
        attack = pd.read_csv('attacks.csv', encoding='latin-1')

# %%
 #Se eliminan aquellos valores que en la columna Date sean Nan
attack = attack.dropna(subset='Date')

# %%
 #Mediante un regex se buscan aquellos valores que pueden contener una fecha
attack = attack[attack.Date.str.contains('([0-9]{2}\-([0-9]{2}|[A-Za-z]{3,4})\-[0-9]{4}$)|([0-9]{4}$)', regex=True)]

# %%
#Eliminamos los campos que dan problemas de las fechas mediante regex
attack['Date'] = attack.Date.str.replace(r'(Rep.*rt.*d|Early|Summer|Ca\.|[Bb]efore|Circa) ', '')
attack['Date'] = attack.Date.str.replace(r'.* (or|and|&|to|dated|") ', '')
attack['Date'] = attack.Date.str.replace('World War II', '1939-1945')

# %%
 #Eliminamos posibles saltos de página encontrados
attack['Investigator or Source'] = attack['Investigator or Source'].str.replace('\\n', ' ')

# %%
#Convertimos las fechas a Datetime y las que no sea posible las modifica a NaT con la opción de errors='coerce'
attack['Date'] = pd.to_datetime(attack['Date'], errors='coerce')

# %%
attack.to_csv('attacks_clean.csv', sep=';')

# %%
#Ahora vamos con la columna Case Number. Que en realidad se trata de un ID, ya que es un dato único. Para ello lo que hacemos es remplazar toda la columna de 1 a n
attack['Case Number'] = [i+1 for i, val in enumerate(attack['Case Number'])]

# %%
attack
# Out:
#       Case Number       Date    Year        Type    Country             Area  \
# 0               1 2018-06-25  2018.0     Boating        USA       California
# 1               2 2018-06-18  2018.0  Unprovoked        USA          Georgia
# 2               3 2018-06-09  2018.0     Invalid        USA           Hawaii
# 3               4 2018-06-08  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4               5 2018-06-04  2018.0    Provoked     MEXICO           Colima
# ...           ...        ...     ...         ...        ...              ...
# 6292         6207 1862-01-01     0.0  Unprovoked        USA           Hawaii
# 6293         6208 1906-01-01     0.0  Unprovoked  AUSTRALIA              NaN
# 6294         6209 1906-01-01     0.0  Unprovoked  AUSTRALIA              NaN
# 6295         6210 1906-01-01     0.0  Unprovoked  AUSTRALIA              NaN
# 6296         6211 1906-01-01     0.0  Unprovoked  AUSTRALIA  New South Wales
#
# ...

# %%
#ahora los valores del año que no contienen info  son ceros, los quiero convertir al año de la columna Date mediante la función .apply
attack['Year'] = attack['Date'].apply(lambda x: x.year)

# %%
attack
# Out:
#       Case Number       Date    Year        Type    Country             Area  \
# 0               1 2018-06-25  2018.0     Boating        USA       California
# 1               2 2018-06-18  2018.0  Unprovoked        USA          Georgia
# 2               3 2018-06-09  2018.0     Invalid        USA           Hawaii
# 3               4 2018-06-08  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4               5 2018-06-04  2018.0    Provoked     MEXICO           Colima
# ...           ...        ...     ...         ...        ...              ...
# 6292         6207 1862-01-01  1862.0  Unprovoked        USA           Hawaii
# 6293         6208 1906-01-01  1906.0  Unprovoked  AUSTRALIA              NaN
# 6294         6209 1906-01-01  1906.0  Unprovoked  AUSTRALIA              NaN
# 6295         6210 1906-01-01  1906.0  Unprovoked  AUSTRALIA              NaN
# 6296         6211 1906-01-01  1906.0  Unprovoked  AUSTRALIA  New South Wales
#
# ...

# %%
attack.info(memory_usage='deep')

#Me doy cuenta que siguen habiendo valores NaN en la columna de año, por lo que los convierto en 'unknown'
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6211 entries, 0 to 6296
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             6211 non-null   int64
#  1   Date                    6118 non-null   datetime64[ns]
#  2   Year                    6118 non-null   float64
#  3   Type                    6207 non-null   object
#  4   Country                 6163 non-null   object
#  5   Area                    5769 non-null   object
#  6   Location                5689 non-null   object
#  7   Activity                5680 non-null   object
#  8   Name                    6008 non-null   object
#  9   Sex                     5653 non-null   object
#  10  Age                     3447 non-null   object
#  11  Injury                  6183 non-null   object
#  12  Fatal (Y/N)             5681 non-null   object
#  13  Time                    2931 non-null   object
# ...

# %%
""" veo que los valores nulos de la columna Date y Year son los mismo y el número es pequeño por lo que los puedo eliminar"""
attack.dropna(subset=['Year'], inplace=True)

# %%
attack.shape
# Out:
# (6118, 24)

# %%
 #ahora puedo convertir los años a enteros
attack['Year'] = attack['Year'].astype(int)

# %%
""" Ahora me fijo en otras columnas que puedan estar relacionadas entre ellas, por ejemplo 'Area' y 'Location' y 'Country'"""
# Out:
# " Ahora me fijo en otras columnas que puedan estar relacionadas entre ellas, por ejemplo 'Area' y 'Location' y 'Country'"

# %%
#En las columnas que tienen un bajo porcentaje de valores nulos directamente los convierto a 'Unknown' para poder trabajar con ellos.
#por ejemplo la columna 'Country' tiene un porcentaje muy bajo y la necesito para poder trabajar las columnas 'Area' y 'Location'
""" Ahora voy a rellenar la columna Area a traves de la columna  Country, po lo que necesito que los valores Nulos se conviertan en 'Unknown'
Después calculo la moda de los valores de Area en Country,mediante .gropuby y generando un diccionario puedo 
rellenar los valores de Área con la moda de los valores únicos de country."""
# Out:
# " Ahora voy a rellenar la columna Area a traves de la columna  Country, po lo que necesito que los valores Nulos se conviertan en 'Unknown'\nDespués calculo la moda de los valores de Area en Country,mediante .gropuby y generando un diccionario puedo \nrellenar los valores de Área con la moda de los valores únicos de country."

# %%
attack['Country'].fillna('Unknown', inplace=True)

# %%
attack['Country'] = attack['Country'].astype(str)

# %%
attack['Area'].fillna('Unknown', inplace=True)

# %%
moda_por_pais = attack.groupby('Country')['Area'].apply(lambda x: x.value_counts().idxmax())
moda_por_pais_dict = moda_por_pais.to_dict()

attack['Area'] = attack.apply(lambda row: moda_por_pais_dict[row['Country']] if row['Area'] == 'Unknown' else row['Area'], axis=1)

# %%
attack
# Out:
#       Case Number       Date  Year        Type    Country             Area  \
# 0               1 2018-06-25  2018     Boating        USA       California
# 1               2 2018-06-18  2018  Unprovoked        USA          Georgia
# 2               3 2018-06-09  2018     Invalid        USA           Hawaii
# 3               4 2018-06-08  2018  Unprovoked  AUSTRALIA  New South Wales
# 4               5 2018-06-04  2018    Provoked     MEXICO           Colima
# ...           ...        ...   ...         ...        ...              ...
# 6292         6207 1862-01-01  1862  Unprovoked        USA           Hawaii
# 6293         6208 1906-01-01  1906  Unprovoked  AUSTRALIA  New South Wales
# 6294         6209 1906-01-01  1906  Unprovoked  AUSTRALIA  New South Wales
# 6295         6210 1906-01-01  1906  Unprovoked  AUSTRALIA  New South Wales
# 6296         6211 1906-01-01  1906  Unprovoked  AUSTRALIA  New South Wales
#
# ...

# %%
moda_por_pais = attack.groupby('Country')['Area'].apply(lambda x: x.value_counts().idxmax())
moda_por_pais_dict = moda_por_pais.to_dict()

attack['Area'] = attack.apply(lambda row: moda_por_pais_dict[row['Country']] if row['Area'] == 'Unknown' else row['Area'], axis=1)

# %%
nan_cols = attack.isna().mean()  * 100  # porcentaje de nulo en cada columna

nan_cols[nan_cols>0]
# Out:
# Type                       0.065381
# Location                   8.221641
# Activity                   8.385093
# Name                       3.285387
# Sex                        8.940830
# Age                       43.870546
# Injury                     0.375940
# Fatal (Y/N)                8.564890
# Time                      52.239294
# Species                   44.606080
# Investigator or Source     0.277869
# href formula               0.016345
# Unnamed: 22               99.983655
# Unnamed: 23               99.967310
# dtype: float64

# %%
"""Observo que la columna 'Type', 'Name', 'Injury' 'Investigator Source' y 'href formula' 
tiene un porcentaje de nulos muy bajo por lo que puedo rellenar con unknows de momento."""
attack['Type'].fillna('Unknown', inplace=True)

# %%
attack['Name'].fillna('Unknown', inplace=True)

# %%
attack['Injury'].fillna('Unknown', inplace=True)

# %%
attack['Investigator or Source'].fillna('Unknown', inplace=True)

# %%
attack['href formula'].fillna('Unknown', inplace=True)

# %%
nan_cols = attack.isna().mean()  * 100  # porcentaje de nulo en cada columna

nan_cols[nan_cols>0]
# Out:
# Location        8.221641
# Activity        8.385093
# Sex             8.940830
# Age            43.870546
# Fatal (Y/N)     8.564890
# Time           52.239294
# Species        44.606080
# Unnamed: 22    99.983655
# Unnamed: 23    99.967310
# dtype: float64

# %%
""" Ahora para mi columna Objetivo, veo que muchos de sus valores nulos, pueden ser rellenos a partir de la columna 'Injury'
por lo que creo una función Lambda para recorrer toda la columna 'Injury' y si la palabra FATAL,
está incluida en la columna, entonces me rellena con Y y sino con N."""
attack['Fatal (Y/N)'] = attack.apply(lambda row: 'Y' if 'FATAL' in row['Injury'].upper() else 'N' if pd.isna(row['Fatal (Y/N)']) else row['Fatal (Y/N)'], axis=1)

# %%
nan_cols = attack.isna().mean()  * 100  # porcentaje de nulo en cada columna

nan_cols[nan_cols>0]
# Out:
# Location        8.221641
# Activity        8.385093
# Sex             8.940830
# Age            43.870546
# Time           52.239294
# Species        44.606080
# Unnamed: 22    99.983655
# Unnamed: 23    99.967310
# dtype: float64

# %%
"""Podemos aplicar el mismo codigo para rellenar la columna 'Sex'
atraves de la columna 'pdf' la cual contiene algún dato que nos ayuda a saber el sexo, como palabra Boy 
o girl"""
# Out:
# "Podemos aplicar el mismo codigo para rellenar la columna 'Sex'\natraves de la columna 'pdf' la cual contiene algún dato que nos ayuda a saber el sexo, como palabra Boy \no girl"

# %%
attack['Sex '] = attack.apply(lambda row: 'M' if '[Bb]oy' in row['pdf'].upper() else 'F' if '[Gg]irl' in row['pdf'].upper() else 'Unknown' if pd.isna(row['Sex ']) else row['Sex '], axis=1)

# %%
nan_cols = attack.isna().mean()  * 100  # porcentaje de nulo en cada columna

nan_cols[nan_cols>0]
# Out:
# Location        8.221641
# Activity        8.385093
# Age            43.870546
# Time           52.239294
# Species        44.606080
# Unnamed: 22    99.983655
# Unnamed: 23    99.967310
# dtype: float64

# %%
""" Para limpiar la columna Location podríamos limpiarla a través de la columna Area, al igual que hicimos
cogiendo su Moda"""
# Out:
# ' Para limpiar la columna Location podríamos limpiarla a través de la columna Area, al igual que hicimos\ncogiendo su Moda'

# %%
#Primero relleno los valores NaN por Unknowns en la columna 'Location'
attack['Location'].fillna('Unknown', inplace=True)

# %%
moda_por_area = attack.groupby('Area')['Location'].apply(lambda x: x.value_counts().idxmax())
moda_por_area_dict = moda_por_area.to_dict()

attack['Location'] = attack.apply(lambda row: moda_por_area_dict[row['Area']] if row['Location'] == 'Unknown' else row['Location'], axis=1)

# %%
attack
# Out:
#       Case Number       Date  Year        Type    Country             Area  \
# 0               1 2018-06-25  2018     Boating        USA       California
# 1               2 2018-06-18  2018  Unprovoked        USA          Georgia
# 2               3 2018-06-09  2018     Invalid        USA           Hawaii
# 3               4 2018-06-08  2018  Unprovoked  AUSTRALIA  New South Wales
# 4               5 2018-06-04  2018    Provoked     MEXICO           Colima
# ...           ...        ...   ...         ...        ...              ...
# 6292         6207 1862-01-01  1862  Unprovoked        USA           Hawaii
# 6293         6208 1906-01-01  1906  Unprovoked  AUSTRALIA  New South Wales
# 6294         6209 1906-01-01  1906  Unprovoked  AUSTRALIA  New South Wales
# 6295         6210 1906-01-01  1906  Unprovoked  AUSTRALIA  New South Wales
# 6296         6211 1906-01-01  1906  Unprovoked  AUSTRALIA  New South Wales
#
# ...

# %%
nan_cols = attack.isna().mean()  * 100  # porcentaje de nulo en cada columna

nan_cols[nan_cols>0]
# Out:
# Activity        8.385093
# Age            43.870546
# Time           52.239294
# Species        44.606080
# Unnamed: 22    99.983655
# Unnamed: 23    99.967310
# dtype: float64

# %%
#no encuentro correlación de la columna Activity con otras columnas por lo que la relleno con 'Unknown'
attack['Activity'].fillna('Unknown', inplace=True)

# %%
#Las columnas Unnamed : 22 y 23 no contienen información relevante, las rellenamos con Unknown ya que no podemos eliminarlas
attack['Unnamed: 22'].fillna('Unknown', inplace=True)

# %%
attack['Unnamed: 23'].fillna('Unknown', inplace=True)

# %%
nan_cols = attack.isna().mean()  * 100  # porcentaje de nulo en cada columna

nan_cols[nan_cols>0]
# Out:
# Age         43.870546
# Time        52.239294
# Species     44.606080
# dtype: float64

# %%
# Me quedan por limpiar ests tres columnas 'Age', 'Time y 'Species'

# %%
# Mi idea es calcular la media de la edad de hombres y mujeres para rellenar los Nan de esta columna.
#para ello debo eliminar primero los Outliners
attack['Age'] = pd.to_numeric(attack['Age'], errors='coerce')

# %%
attack['Age'].fillna('Unknown', inplace=True)

# %%
plt.figure(figsize=(10, 6))


attack.boxplot();

# %%
stats=attack.describe().T

stats['IQR']=stats['75%']-stats['25%']

# test de Tukey
stats['IQR1.5']=1.5 * stats['IQR'] + stats['75%']

stats
# Out:
#                  count         mean          std     min      25%     50%  \
# Case Number     6118.0  3077.740111  1781.586448     1.0  1536.25  3072.5
# Year            6118.0  1968.019614    45.692026  1703.0  1945.00  1980.0
# original order  6118.0  3203.180778  1798.872046     7.0  1644.25  3212.5
#
#                     75%     max     IQR  IQR1.5
# Case Number     4619.75  6211.0  3083.5  9245.0
# Year            2005.00  2018.0    60.0  2095.0
# original order  4759.75  6303.0  3115.5  9433.0

# %%
#la media de edad son 27 años por lo que relleno los valores  NaN con 27.

# %%
attack
# Out:
#       Case Number       Date  Year        Type    Country             Area  \
# 0               1 2018-06-25  2018     Boating        USA       California
# 1               2 2018-06-18  2018  Unprovoked        USA          Georgia
# 2               3 2018-06-09  2018     Invalid        USA           Hawaii
# 3               4 2018-06-08  2018  Unprovoked  AUSTRALIA  New South Wales
# 4               5 2018-06-04  2018    Provoked     MEXICO           Colima
# ...           ...        ...   ...         ...        ...              ...
# 6292         6207 1862-01-01  1862  Unprovoked        USA           Hawaii
# 6293         6208 1906-01-01  1906  Unprovoked  AUSTRALIA  New South Wales
# 6294         6209 1906-01-01  1906  Unprovoked  AUSTRALIA  New South Wales
# 6295         6210 1906-01-01  1906  Unprovoked  AUSTRALIA  New South Wales
# 6296         6211 1906-01-01  1906  Unprovoked  AUSTRALIA  New South Wales
#
# ...

# %%
attack['Age'] = attack['Age'].replace('Unknown', np.NaN)
attack['Age'] = attack['Age'].astype(float)
attack['Age'].fillna(27, inplace=True)
attack['Age'] = attack['Age'].astype(int)

# %%
attack
# Out:
#       Case Number       Date  Year        Type    Country             Area  \
# 0               1 2018-06-25  2018     Boating        USA       California
# 1               2 2018-06-18  2018  Unprovoked        USA          Georgia
# 2               3 2018-06-09  2018     Invalid        USA           Hawaii
# 3               4 2018-06-08  2018  Unprovoked  AUSTRALIA  New South Wales
# 4               5 2018-06-04  2018    Provoked     MEXICO           Colima
# ...           ...        ...   ...         ...        ...              ...
# 6292         6207 1862-01-01  1862  Unprovoked        USA           Hawaii
# 6293         6208 1906-01-01  1906  Unprovoked  AUSTRALIA  New South Wales
# 6294         6209 1906-01-01  1906  Unprovoked  AUSTRALIA  New South Wales
# 6295         6210 1906-01-01  1906  Unprovoked  AUSTRALIA  New South Wales
# 6296         6211 1906-01-01  1906  Unprovoked  AUSTRALIA  New South Wales
#
# ...

# %%
nan_cols = attack.isna().mean()  * 100  # porcentaje de nulo en cada columna

nan_cols[nan_cols>0]
# Out:
# Time        52.239294
# Species     44.606080
# dtype: float64

# %%
#Ahora vamos con la columna 'Time'
#Creamos una funcion para convertirlo todo al mismo formato si fuera posible
def convert_to_time(value):
    try:
        # intentar convertir a float
        float_value = float(value)
        
        # calcular horas, minutos y segundos
        seconds = int(float_value)
        hours = seconds // 3600
        minutes = (seconds % 3600) // 60
        return "{:02d}:{:02d}:{:02d}".format(hours, minutes, seconds)
    except ValueError:
        if isinstance(value, str):
            if "h" in value:
                # formato 7h
                parts = value.split("h")
                return "{}:00:00".format(parts[0].zfill(2))
            else:
                if value == "Morning":
                    return "10:00:00"
                elif value == "Afternoon":
                    return "17:00:00"
                elif value == "Night":
                    return "20:00:00"
                elif value == "Late afternoon":
                    return "18:00:00"
    return value

attack['Time'] = attack['Time'].apply(convert_to_time)

# %%
attack['Time'].fillna('Unknown', inplace=True)

# %%
attack['Species '].fillna('Unknown', inplace=True)

# %%
# contar el número de valores "Unknown" por fila
attack['unknown_count'] = attack.apply(lambda x: (x == 'Unknown').sum(), axis=1)

# %%
attack['unknown_count']
# Out:
# 0       2
# 1       3
# 2       3
# 3       3
# 4       3
#        ..
# 6292    5
# 6293    4
# 6294    4
# 6295    4
# 6296    3
# Name: unknown_count, Length: 6118, dtype: int64

# %%
# calcular el porcentaje de valores "Unknown" por fila
attack['unknown_pct'] = attack['unknown_count'] / attack.shape[1]

# eliminar las filas que contienen más del 40% de valores "Unknown"
attack = attack[attack['unknown_pct'] < 0.4]

# eliminar las columnas 'unknown_count' y 'unknown_pct'
attack = attack.drop(['unknown_count', 'unknown_pct'], axis=1)

# %%
attack.shape
# Out:
# (6118, 24)

# %%
""" Para mi objetivo necesito que haya el menor número de Unknown en la columna País y en la columna 
Fatal"""
# Out:
# ' Para mi objetivo necesito que haya el menor número de Unknown en la columna País y en la columna \nFatal'

# %%
unknown_count_country = attack['Country'].value_counts()['Unknown']

# %%
unknown_count_country
# Out:
# 45

# %%
value_counts_fatal = attack['Fatal (Y/N)'].value_counts()

# %%
value_counts_fatal
# Out:
# N          4658
# Y          1387
# UNKNOWN      63
#  N            7
# M             1
# 2017          1
# N             1
# Name: Fatal (Y/N), dtype: int64

# %%
"""El operador ~ invierte la máscara, de manera que las filas que cumplen la 
condición attack['Fatal (Y/N)'].isin(['UNKNOWN', 'M', '2017']) quedan excluidas."""




mask = ~attack['Fatal (Y/N)'].isin(['UNKNOWN', 'M', '2017'])
attack = attack[mask]

# %%
attack.shape
# Out:
# (6053, 24)

# %%
mask_2 = ~attack['Country'].isin(['Unknown'])
attack = attack[mask_2]

# %%
attack.shape
# Out:
# (6008, 24)

# %%
value_counts_country = attack['Country'].value_counts()

# %%
value_counts_country
# Out:
# USA                 2180
# AUSTRALIA           1293
# SOUTH AFRICA         571
# PAPUA NEW GUINEA     129
# NEW ZEALAND          123
#                     ...
# GRAND CAYMAN           1
# ARGENTINA              1
# SUDAN?                 1
# THE BALKANS            1
# ASIA?                  1
# Name: Country, Length: 201, dtype: int64

# %%
"""He terminado de limpiar las columnas para mi Objetivo"

# %%
value_counts_year =attack['Year'].value_counts()

# %%
value_counts_year
# Out:
# 2015    143
# 2017    135
# 2016    130
# 2014    127
# 2011    124
#        ...
# 1807      1
# 1806      1
# 1805      1
# 1802      1
# 1703      1
# Name: Year, Length: 230, dtype: int64

# %%
attack.to_csv('limpieza_sharks.csv', sep=';')

# %%
attack.to_excel('limpieza_sharks.xlsx')

# %%
# Filtra el data frame por 'Country' igual a 'USA'
attack_usa = attack[attack['Country'] == 'USA']

# Calcula el porcentaje de filas donde 'FATAL (Y/N)' es igual a 'Y'
percentage = (attack_usa['Fatal (Y/N)'] == 'Y').mean() * 100

print('Porcentaje de ataques fatales en USA:', percentage, '%')
# Out:
# Porcentaje de ataques fatales en USA: 9.036697247706423 %
